# %%
from testClass import testclass1

# %%
Q1=testclass1.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision Robotics
# Speech Processing
# Natural Language Processing

# %%
Q2=testclass1.OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number

# %%
Q3=testclass1.Eligible()
# Out:
# Your Gender: Male
# Your Age: 20
# Not Eligible

# %%
Q4=testclass1.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.60000000000001

# %%
Q5=testclass1.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

# %%
if 0:
    print("Hello")
else:
    print("World")
# Out:
# World

# %%
x=5
y=x
x=10
print(y)
# Out:
# 5

# %%
def test():
    return 5
print(test() + 10)
# Out:
# 15

# %%
test()
# Out:
# 5
