# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#This Indentation (spacing error)
#Syntax error for for:
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

#Value of b is in string, so that we cannot use the operator'+'

# %%
##Value of b is in string, so that we need to define as int
a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#syntax error in def
def add_numbers(a, b):
    return a + b
add_numbers(2,3)
# Out:
# 5

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
#Not in range error 
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#Parenthesee missing:
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
#division by 0 is not allowed
x = 5 / 1
x
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#Cannot concatenate string with interger 
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
print("Name: " + name + ", Age: " , age)
# Out:
# Name: Alice, Age: 25
# Name: Alice, Age:  25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
# for given range the change value is not correct or viceversa
for i in range(1, 10, +1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#9. For comparsion we need to use ==
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
# Syntax error in function


def greet(name):
    print("Hello, " + name)
greet("Yamini")
# Out:
# Hello, Yamini
