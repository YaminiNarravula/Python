# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #1.Find the error in the following Python code:
#       2 import math
# ----> 3 print(Math.sqrt(16))
#
# NameError: name 'Math' is not defined

# %%
#1.case sensitive: Math should be lower case
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

def my_function():    
    x += 5
    print(x)

x = 10
my_function()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 9
#       5     x += 5
#       6     print(x)
#       7
#       8 x = 10
# ----> 9 my_function()
#
# Cell In[9], line 5, in my_function()
#       3 def my_function():
#       4
# ----> 5     x += 5
#       6     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
#2. Variable X needs assigned inside function or needs calls as global variable :

def my_function():    
    x = 10
    x += 5
    print(x)


my_function()
# Out:
# 15

# %%
#3.
x = 5
if x = 10:
    print("x is 10")
# Out:
#   Cell In[18], line 3
#     if x = 10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#3. FOr comparsion operator is ==
x = 5
if x == 10:
    print("x is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
# Out:
# None

# %%
#4.sorts the list in place and returns, if passing directly into print it will return none
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))
# Out:
# None

# %%
#5. Corrected code: operation needs to assign to variable or needs return the function
def square(n):
    square=n * n
    print(square)

square(4)
# Out:
# 16

# %%
#5. Corrected code: return the value explicitly 
def square(n):
    return n * n
    
print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#6. Tuple are immutable so that it can be reordered, so that it has changed to list
my_tuple= [1, 2, 3]
my_tuple[1] = 5
print(my_tuple)
# Out:
# [1, 5, 3]

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       1 #7.
#       2 name = "Alice"
#       3 age = 25
# ----> 4 print("My name is %s and I am %d years old" % (name))
#
# TypeError: not enough arguments for format string

# %%
#7. The format placeholders are missing a required argument.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#8. is checks for object identity, not value equality.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#9. range(5, 1) does not produce any numbers because the default step is +1, for decrement use(-1)
for i in range(5, 1,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
# Out:
# John

# %%
#10.Here name is string not a variable
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
